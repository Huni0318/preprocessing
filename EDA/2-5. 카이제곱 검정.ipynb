# %% [markdown]
# ## 카이제곱 검정 개요
# - 목적 : 두 범주형 변수가 서로 독립적인지 검정
# - 귀무가설과 대립가설
# ![image.png](attachment:image.png)

# %% [markdown]
# - 교차 테이블(contingency table)은 두 변수가 취할 수 있는 값의 조합의 출현 빈도를 나타냄
# ![2-5-2.PNG](attachment:2-5-2.PNG)

# %% [markdown]
# ![2-5-3.PNG](attachment:2-5-3.PNG)

# %% [markdown]
# ## 카이제곱 통계량
# ![2-5-4.PNG](attachment:2-5-4.PNG)
# - 기대값과 실제값의 차이가 클수록 통계량이 커지며, 통계량이 커질수록 귀무가설이 기각될 가능성이 높아짐(즉, p-value가 감소함)

# %% [markdown]
# ![2-5-5.PNG](attachment:2-5-5.PNG)

# %%
import os
import pandas as pd

os.chdir(r'C:\Users\신상훈\Desktop\preprocessing\part-2.-탐색적-데이터-분석\2. 탐색적 데이터 분석\데이터')

# %%
df = pd.read_csv('성별에따른만족도.csv', engine = 'python')
df.head()
# Out:
#    만족도  성별
# 0  불만족  남성
# 1   보통  여성
# 2  불만족  여성
# 3   보통  남성
# 4   만족  여성

# %%
# 교차 테이블 생성
cross_table = pd.crosstab(df['만족도'], df['성별'])
cross_table
# Out:
# 성별   남성  여성
# 만족도
# 만족   50  40
# 보통   40  30
# 불만족  10  30

# %%
obs = cross_table.values
obs
# Out:
# array([[50, 40],
#        [40, 30],
#        [10, 30]], dtype=int64)

# %%
from scipy.stats import *
statistics, pvalue, dof, expected = chi2_contingency(obs)
print(pvalue) # pvalue가 0.0018로 두 변수 간 독립이 아님을 확인
# Out:
# 0.001892528960792166

# %%
# 기대값
pd.DataFrame(expected, columns = cross_table.columns, index = cross_table.index)
# Out:
# 성별     남성    여성
# 만족도
# 만족   45.0  45.0
# 보통   35.0  35.0
# 불만족  20.0  20.0

# %%
dof
# Out:
# 2

# %%
statistics
# Out:
# 12.53968253968254
