# %%
import os
import pandas as pd
os.chdir(r'C:\Users\신상훈\Desktop\preprocessing\part-1.-데이터-핸들링\1. 데이터 핸들링\데이터')

# %%
df = pd.read_csv('온라인_판매기록.csv',engine = 'python')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.head()
# Out:
#   쇼핑몰     제품  수량     판매금액 쇼핑몰 유형
# 0  쿠팡  제품_16   8  1134400     쿠팡
# 1  쿠팡  제품_57   8   439200     쿠팡
# 2  쿠팡  제품_25   4   495200     쿠팡
# 3  쿠팡  제품_18   4   578000     쿠팡
# 4  쿠팡  제품_90   2    75000     쿠팡

# %%
df[['수량','판매금액']].mean()
# Out:
# 수량           5.502837
# 판매금액    448851.831470
# dtype: float64

# %% [markdown]
# ### axis 키워드
# - axis키워드는 그 함수의 결과 구조가 벡터 형태(1차원)인지, 행렬 형태(2차원)인지에 따라, 그역할이 조금씩 다름
# ![2-3-2.PNG](attachment:2-3-2.PNG)

# %%
df[['수량', '판매금액']].quantile(0.1)
# Out:
# 수량          2.0
# 판매금액    79700.0
# Name: 0.1, dtype: float64

# %%
df[['수량', '판매금액']].describe()
# Out:
#                 수량          판매금액
# count  5815.000000  5.815000e+03
# mean      5.502837  4.488518e+05
# std       2.867373  3.491219e+05
# min       1.000000  1.010000e+04
# 25%       3.000000  1.528000e+05
# 50%       6.000000  3.584000e+05
# 75%       8.000000  6.678000e+05
# max      10.000000  1.533000e+06
