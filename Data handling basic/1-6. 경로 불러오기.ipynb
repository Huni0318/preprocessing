# %% [markdown]
# ## 경로 확인하기 및 설정하기
# - 파이썬에서 데이터를 불러오려면 반드시 경로와 확장자까지 포함시켜서 불러와야 한다.
# - 경로를 성정함으로써 파일을 불러올 때마다 경로를 포함시키는 번거로움을 해결한다.
# - os 모듈에 속한 함수를 사용하면 경로를 확인하고 설정할 수 있다.
# ![image.png](attachment:image.png)

# %% [markdown]
# - \(역슬래시)는 프로그래밍 언어에서 중요한 기능을 하므로 틀별한 표현이 아님을 나타내야함
# ![1-6-2.PNG](attachment:1-6-2.PNG)

# %%
import os
os.getcwd() # 현재 경로 확인
# Out:
# 'C:\\Users\\신상훈\\Documents\\GitHub\\preprocessing\\Data handling basic'

# %%
os.chdir(r'C:\Users\신상훈\Desktop\preprocessing\part-1.-데이터-핸들링\1. 데이터 핸들링\데이터')

# %%
open('sample folder/sample data.txt')
# Out:
# <_io.TextIOWrapper name='sample folder/sample data.txt' mode='r' encoding='cp949'>

# %%
open("sample folder/sample folder2/sample data2.txt")
# Out:
# <_io.TextIOWrapper name='sample folder/sample folder2/sample data2.txt' mode='r' encoding='cp949'>
